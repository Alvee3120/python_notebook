# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvee3120/python_notebook/blob/main/Different_Ways_Of_Creating_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Nov 27 17:44:05 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1st Way

# %%
import pandas as pd

df= pd.read_csv(r'/content/drive/MyDrive/Python Practice/weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# 2nd Way

# %%
df= pd.read_excel(r'/content/drive/MyDrive/Python Practice/weather_data.xlsx','Sheet1')
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %% [markdown]
# 3rd Way

# %%
our_data = {
  'Name' : ['Alvee','Mahia', 'Mitu', 'Hridoy'],
 'Date of Birth' : ['22/11', '10/12', '14/11','5/6']

}
pf= pd.DataFrame(our_data)
pf
# Out:
#      Name Date of Birth
# 0   Alvee         22/11
# 1   Mahia         10/12
# 2    Mitu         14/11
# 3  Hridoy           5/6

# %% [markdown]
# 4th Way

# %%
our_data = {
('Alvee','22/11'),
('Mahia','10/12'),
('Mitu','14/11'),
('Hridoy','5/6')
}
pf= pd.DataFrame(our_data, columns=['Name','Date of Birth'])
pf
# Out:
#      Name Date of Birth
# 0   Alvee         22/11
# 1   Mahia         10/12
# 2    Mitu         14/11
# 3  Hridoy           5/6
